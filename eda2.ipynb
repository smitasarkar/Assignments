# %%
df=pd.read_csv("ml_data.csv")

# %%
import pandas as pd

# %%
df.head()
# Out:
#    HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  HeartDiseaseorAttack  \
# 0       1         1          0   28       1       0                     0
# 1       0         0          1   24       0       0                     0
# 2       1         0          1   32       0       0                     1
# 3       0         0          1   25       1       0                     0
# 4       1         1          1   26       1       0                     0
#
#    PhysActivity  Fruits  Veggies  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0             1       1        1  ...            1        3         0
# 1             1       1        1  ...            0        2         0
# 2             1       1        1  ...            0        2         0
# 3             1       1        1  ...            0        2         0
# 4             1       1        0  ...            0        2         3
#
#    PhysHlth  DiffWalk  Sex  Age  Education  Income  target
# ...

# %%
df.describe()
# Out:
#               HighBP       HighChol     CholCheck            BMI  \
# count  228312.000000  228312.000000  228312.00000  228312.000000
# mean        0.429014       0.424660       0.96274      28.387535
# std         0.494936       0.494292       0.18940       6.617483
# min         0.000000       0.000000       0.00000      12.000000
# 25%         0.000000       0.000000       1.00000      24.000000
# 50%         0.000000       0.000000       1.00000      27.000000
# 75%         1.000000       1.000000       1.00000      31.000000
# max         1.000000       1.000000       1.00000      98.000000
#
#               Smoker         Stroke  HeartDiseaseorAttack   PhysActivity  \
# count  228312.000000  228312.000000         228312.000000  228312.000000
# mean        0.443380       0.040620              0.094358       0.756535
# std         0.496785       0.197408              0.292326       0.429174
# min         0.000000       0.000000              0.000000       0.000000
# ...

# %%
# Count the number of instances in each class
class_counts = df['target'].value_counts()

# Print the class counts
print(class_counts)
# Out:
# target
# 0    192333
# 2     31811
# 1      4168
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE

# Split the dataframe into features and target variables
X = df.drop('target', axis=1)
y = df['target']

# Over-sample the minority class
X_resampled, y_resampled = SMOTE().fit_resample(X, y)

# Combine the over-sampled data with the original data
df_resampled = pd.concat([X_resampled, y_resampled], axis=1)

# %%
# Count the number of instances in each class
class_counts = df_resampled['target'].value_counts()

# Print the class counts
print(class_counts)
# Out:
# target
# 0    192333
# 2    192333
# 1    192333
# Name: count, dtype: int64

# %%
df_resampled.to_csv('smote_data.csv', index=False)

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import ADASYN

# Split the dataframe into features and target variables
X = df.drop('target', axis=1)
y = df['target']

# Create an instance of the ADASYN class
adasyn = ADASYN()

# Over-sample the minority class
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Combine the over-sampled data with the original data
df_adasyn = pd.concat([X_resampled, y_resampled], axis=1)

# %%
# Count the number of instances in each class
class_counts = df_adasyn['target'].value_counts()

# Print the class counts
print(class_counts)
# Out:
# target
# 1    192918
# 2    192871
# 0    192333
# Name: count, dtype: int64

# %%
df_adasyn.to_csv('adasyn_data.csv', index=False)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
dftest=pd.read_csv("test_data.csv")
